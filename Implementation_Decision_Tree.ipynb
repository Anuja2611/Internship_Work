# %%
# Importing Libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# importing dataset

ds = pd.read_csv('Position_Salaries.csv')
ds
# Out:
#             Position  Level   Salary
# 0   Business Analyst      1    45000
# 1  Junior Consultant      2    50000
# 2  Senior Consultant      3    60000
# 3            Manager      4    80000
# 4    Country Manager      5   110000
# 5     Region Manager      6   150000
# 6            Partner      7   200000
# 7     Senior Partner      8   300000
# 8            C-level      9   500000
# 9                CEO     10  1000000

# %%
# Splitting dataset
x=ds[['Level']]
y=ds[['Salary']]

# %%
# Fitting Decision Tree Regression model

from sklearn.tree import DecisionTreeRegressor , plot_tree
reg = DecisionTreeRegressor(random_state = 0)
reg.fit(x,y)
# Out:
# DecisionTreeRegressor(random_state=0)

# %%
# Visualization

plt.scatter(x,y)
plt.show()

# %%
# Prediction

myinput = pd.DataFrame(data = [[4]] , columns=['Level'])
reg.predict(myinput)
# Out:
# array([80000.])

# %%
# Visualize decision tree
plt.figure(figsize=(50,50))      # set size of figure
plot_tree(reg , feature_names = ['Level'] , filled = True)
plt.title('Decision tree Visualization')
plt.show()

# %%
# user input

level = float(input('Enter Level : '))
myinput=pd.DataFrame(data=[[level]] , columns = ['Level'])
result = reg.predict(myinput)
print(f'Predict Salary for Level {level} : {round(result[0])}')
# Out:
# Enter Level :  5
# Predict Salary for Level 5.0 : 110000
