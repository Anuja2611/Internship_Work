# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
ds = pd.read_csv("employee_dataset_for_eda.csv")

# %%
ds
# Out:
#      Employee_ID  Age  Gender   Department       Location  \
# 0           1001   50  Female    Marketing         Austin
# 1           1002   36  Female        Sales       New York
# 2           1003   29    Male    Marketing  San Francisco
# 3           1004   42  Female           HR  San Francisco
# 4           1005   40  Female    Marketing         Austin
# ..           ...  ...     ...          ...            ...
# 195         1196   40  Female           HR       New York
# 196         1197   41    Male      Finance  San Francisco
# 197         1198   53    Male           HR       New York
# 198         1199   28  Female           HR         Austin
# 199         1200   54    Male  Engineering         Austin
#
#      Years_of_Experience  Monthly_Salary  Performance_Score
# 0                      4          105046               79.6
# 1                      1           59287               71.7
# 2                      5           69711               87.2
# ...

# %%
ds.head()
# Out:
#    Employee_ID  Age  Gender Department       Location  Years_of_Experience  \
# 0         1001   50  Female  Marketing         Austin                    4
# 1         1002   36  Female      Sales       New York                    1
# 2         1003   29    Male  Marketing  San Francisco                    5
# 3         1004   42  Female         HR  San Francisco                    1
# 4         1005   40  Female  Marketing         Austin                   12
#
#    Monthly_Salary  Performance_Score
# 0          105046               79.6
# 1           59287               71.7
# 2           69711               87.2
# 3           41954               74.4
# 4          103340               82.5

# %%
ds.tail()
# Out:
#      Employee_ID  Age  Gender   Department       Location  \
# 195         1196   40  Female           HR       New York
# 196         1197   41    Male      Finance  San Francisco
# 197         1198   53    Male           HR       New York
# 198         1199   28  Female           HR         Austin
# 199         1200   54    Male  Engineering         Austin
#
#      Years_of_Experience  Monthly_Salary  Performance_Score
# 195                   12           93230               67.3
# 196                    9          104055               58.3
# 197                   17           86373               62.6
# 198                    7           61480               60.7
# 199                    7          115230               75.9

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Employee_ID          200 non-null    int64
#  1   Age                  200 non-null    int64
#  2   Gender               200 non-null    object
#  3   Department           200 non-null    object
#  4   Location             200 non-null    object
#  5   Years_of_Experience  200 non-null    int64
#  6   Monthly_Salary       200 non-null    int64
#  7   Performance_Score    200 non-null    float64
# dtypes: float64(1), int64(4), object(3)
# memory usage: 12.6+ KB

# %% [markdown]
# # Categorical Variable Visualisation

# %%
# Employee count per Department

sns.countplot(data=ds , x="Department" , palette="Set2")
plt.title("Employee count per Department")
# Out:
# C:\Users\swaro\AppData\Local\Temp\ipykernel_13008\1486534836.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=ds , x="Department" , palette="Set2")
# Text(0.5, 1.0, 'Employee count per Department')

# %% [markdown]
# # interpretation :
# Finanace is more than marketing and engineering

# %%
#Gender Distribution
sns.countplot(data=ds , x="Gender" , palette = "coolwarm")
plt.title("Gender Distribution")
# Out:
# C:\Users\swaro\AppData\Local\Temp\ipykernel_13008\3679725146.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=ds , x="Gender" , palette = "coolwarm")
# Text(0.5, 1.0, 'Gender Distribution')

# %% [markdown]
# # Interpretation
# Female count is greater than male count

# %%
#employee LOcation Distribution

sns.countplot(data=ds , x="Location" , palette="Spectral")
plt.title("Number of Employee by Location")
plt.xticks(rotation=45)
# Out:
# C:\Users\swaro\AppData\Local\Temp\ipykernel_13008\4020264919.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=ds , x="Location" , palette="Spectral")
# ([0, 1, 2, 3, 4],
#  [Text(0, 0, 'Austin'),
#   Text(1, 0, 'New York'),
#   Text(2, 0, 'San Francisco'),
#   Text(3, 0, 'Seattle'),
#   Text(4, 0, 'Chicago')])

# %% [markdown]
# # Interpretation :
# Employees are spread across different location, with some locations having more employees than others

# %%
#Age Distribution

sns.histplot(ds["Age"] , bins=10 , kde=True)
plt.title("Age Ditrubution")
# Out:
# Text(0.5, 1.0, 'Age Ditrubution')

# %% [markdown]
# # Interpretation
# peak at 25-30 & 45-50

# %%
# Years of Experience Distribution

sns.histplot(ds["Years_of_Experience"], bins=15,kde=True)
plt.title("Years of Experience")
# Out:
# Text(0.5, 1.0, 'Years of Experience')

# %% [markdown]
# # Interpretation
# The distribution of years is bimodal , with peak around 4-5 and 10-15 years,indicating two dominant experience groups

# %%
# monthly Salary Distribution
sns.boxplot(data=ds , y="Monthly_Salary" , color="lightblue")
plt.title("Salary Spread")
# Out:
# Text(0.5, 1.0, 'Salary Spread')

# %% [markdown]
# # Interpretation
# data is fairly spread,showing salary variation

# %%
# Average Salary by Department
sns.barplot(data=ds , x="Department" , y="Monthly_Salary" , estimator=np.mean , palette="pink")
plt.title("Average Salary by Department")
# Out:
# C:\Users\swaro\AppData\Local\Temp\ipykernel_13008\550451343.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=ds , x="Department" , y="Monthly_Salary" , estimator=np.mean , palette="pink")
# Text(0.5, 1.0, 'Average Salary by Department')

# %% [markdown]
# # Interpretation
# some dapartments have higher performance scores than others which could be due to the type of work or team efficiency

# %%
# performane score by Department

sns.boxplot(data=ds , x="Department" , y="Performance_Score" ,palette="pink")
plt.title("Performance Score by Department")
# Out:
# C:\Users\swaro\AppData\Local\Temp\ipykernel_13008\3953134891.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=ds , x="Department" , y="Performance_Score" ,palette="pink")
# Text(0.5, 1.0, 'Performance Score by Department')

# %% [markdown]
# # Intrepretation
# some departments have higher performance than others , which could be due to the type of work or team efficiency

# %%
# Salary Distribution by Gender
sns.violinplot(data=ds , x="Gender" , y="Monthly_Salary" , palette="muted")
plt.title("Salary by Gender")
# Out:
# C:\Users\swaro\AppData\Local\Temp\ipykernel_13008\4157119907.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data=ds , x="Gender" , y="Monthly_Salary" , palette="muted")
# Text(0.5, 1.0, 'Salary by Gender')

# %% [markdown]
# # Interpretation
# There is small diffrence in average salary between males and females which may be due to job roles  or experience.

# %%
sns.heatmap(ds[["Age" , "Years_of_Experience" , "Monthly_Salary","Performance_Score"]].corr(),annot=True , cmap="coolwarm")
plt.title("Correlation Matrix")
# Out:
# Text(0.5, 1.0, 'Correlation Matrix')

# %% [markdown]
# # Interpretation
# Dark blue indicates negative correlation and others indicates positive correlation

# %%
# salary vs Experience Scatter Plot
sns.scatterplot(data=ds , x="Years_of_Experience" , y="Monthly_Salary",hue="Department")
plt.title("Salary vs. Experience by Department")
# Out:
# Text(0.5, 1.0, 'Salary vs. Experience by Department')

# %% [markdown]
# # Interpretation
# as years of experience increases salary increases
